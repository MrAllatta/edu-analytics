# %%
import pandas
df = pandas.read_csv("/home/teacher/projects/edu-analytics/data/school_quality.csv")

# %% [markdown]
# This dataset is near and dear to my heart. School quality data, first report year 2016, the year of AFSE's first graduating class. I introduced Young Guru as our graduation speaker.

# %%
df.columns
# Out:
# Index(['School Year', 'Report Year',
#        'District, Borough and School Number (DBN)', 'School Name',
#        'Report Type', 'School Type', 'Metric Variable Name',
#        'Metric Display Name', 'Number of Students', 'Metric Value',
#        'Comparison Group Average', 'Metric Score'],
#       dtype='object')

# %%
df[["School Year", "Report Year"]].drop_duplicates().sort_values(by="Report Year")
# Out:
#         School Year  Report Year
# 909866         2015         2016
# 212285         2016         2017
# 952            2017         2018
# 151558         2018         2019
# 29472          2019         2020
# 0              2020         2021
# 381429         2021         2022
# 576349         2022         2023
# 990763         2023         2024
# 733            2024         2025

# %%
pattern = r'^ccr_(?:[a-z0-9]+_)*[a-z0-9]+$'
ccr = df[df["Metric Variable Name"].str.contains(pattern, regex=True, na=False)]

# %%
ccr[]

# %%
grouped = df.group_by()
